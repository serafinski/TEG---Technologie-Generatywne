# %% [markdown]
# # Tasks for today
#
# 1. Create simple RAG
# 2. Go to RAG Techniques Repo
# 3. Choose 3 pairs of additional modules that can improve our RAG
# 4. Choose 3 different Prompt Engineering Techniques that can improve our RAG
# 5. Implement these in Python and create comparison - we should have 6 outputs per input
# 6. Ask 3 questions to your data and generate dataframe (3 x 6 rows) with evaluation
# 7. Evaluation will use at least 3 RAGAs metrics, but also send it to new instance of LLM (discriminator)
# 8. Create streamlit/gradio app that will be a frontend for such comparison - user query, processing, show results
#
# What to remember:
# * Do it as your Portfolio project
# * Specify functions parameters types
# * Remember about error handling
# * Remember about SOLID principles
# * Create baseline and extend it using modules and prompts

# %% [markdown]
# # Models responses

# %% [markdown]
# ### Google Gemini GenAI

# %% [markdown]
# ##### You can get api_key [here](https://ai.google.dev/gemini-api/docs/api-key) ([Gemini Flash is free](https://ai.google.dev/gemini-api/docs/pricing))

# %%
from google import genai

client = genai.Client(
    api_key='AIzaSyAptshCnciZCVPK7vPcwjK8jQPCnKmvJqo'
)

response = client.models.generate_content(
    model='gemini-2.0-flash', 
    contents='How does RLHF work?'
)

print(response)
# Out:
# candidates=[Candidate(content=Content(parts=[Part(video_metadata=None, thought=None, code_execution_result=None, executable_code=None, file_data=None, function_call=None, function_response=None, inline_data=None, text='RLHF, or Reinforcement Learning from Human Feedback, is a powerful technique used to fine-tune large language models (LLMs) to better align with human preferences and intentions. It addresses a key challenge in LLM development: while models can generate fluent and seemingly intelligent text, they don\'t always produce outputs that are helpful, harmless, and honest (HHH). RLHF acts as a layer on top of pre-trained LLMs, shaping their behavior through human feedback.\n\nHere\'s a breakdown of the RLHF process, typically involving three main stages:\n\n**1. Supervised Fine-Tuning (SFT):**\n\n*   **Purpose:** Provides a foundational understanding of desired behavior.\n*   **Process:**\n    *   A pre-trained LLM (e.g., a model trained on a vast corpus of text and code) is f
# ...

# %%
response = client.models.generate_content(
    model='gemini-2.0-flash', 
    contents=f'Parse this message to JSON: {response}'
)

print(response.text)
# Out:
# ```json
# {
#   "candidates": [
#     {
#       "content": {
#         "parts": [
#           {
#             "video_metadata": null,
#             "thought": null,
#             "code_execution_result": null,
#             "executable_code": null,
#             "file_data": null,
#             "function_call": null,
#             "function_response": null,
#             "inline_data": null,
# ...

# %% [markdown]
# ### Langchain's Interface to Gemini

# %%
# To po prostu nie da metadanych
from langchain_google_genai import GoogleGenerativeAI

llm = GoogleGenerativeAI(
    api_key='AIzaSyAptshCnciZCVPK7vPcwjK8jQPCnKmvJqo',
    model="gemini-2.0-flash"
)

response = llm.invoke("How does RLHF work?")

response
# Out:
# 'RLHF, or Reinforcement Learning from Human Feedback, is a technique used to fine-tune large language models (LLMs) to better align with human preferences. It\'s a crucial step in making models more helpful, harmless, and truthful. Here\'s a breakdown of how it works:\n\n**1. Pre-trained Language Model (LM):**\n\n*   You start with a large language model (LM) that has been pre-trained on a massive dataset of text and code. This initial model can generate text, translate languages, write different kinds of creative content, and answer your questions in an informative way.  Think of models like GPT-3, LLaMA, or PaLM before they were specifically aligned.\n\n**2. Data Collection and Labeling (Human Feedback):**\n\n*   **Prompt Generation:**  A set of diverse prompts is created, designed to elicit different types of responses from the LM. These prompts cover a wide range of topics, tasks, and user intents.\n*   **LM Response Generation:**  The LM is used to generate multiple responses (u
# ...

# %% [markdown]
# # RAG Techniques

# %% [markdown]
# [RAG Techniques Repo](https://github.com/NirDiamant/RAG_Techniques/tree/main)

# %% [markdown]
# [Prompt Engineering Techniques Repo](https://github.com/NirDiamant/Prompt_Engineering)

# %% [markdown]
# [Great GenAI learning Repo](https://github.com/promptslab/Awesome-Prompt-Engineering)

# %% [markdown]
# # Prompt Engineering

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# [Good summary on RAG Architectures](https://www.linkedin.com/posts/digitalprocessarchitect_20-rag-techniques-explained-activity-7308117598716465154-Jbjb?utm_source=share&utm_medium=member_desktop&rcm=ACoAACkIsHsBP3e1U1liORnXUOPjxbjsaUZAPHA)
